# %%
#DenseNet121
import matplotlib.pyplot as plt

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
test_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy, color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for DenseNet-121 ')
fig.tight_layout()
plt.savefig("DenseNet121_20_p001.pdf")

# Show plot
plt.show()

print("Average Test Accuracy(%):"+str(average(training_accuracy)))
print("Average Highest Test Accuracy(%):"+str(max(training_accuracy)))
# Out:
# Average Test Accuracy(%):81.86699999999999
# Average Highest Test Accuracy(%):91.83

# %%
def average(m) :
    return sum(m)/len(m)

# %%
#for ResNet18
import re

# Sample text
text = """
Epoch 1/20, Loss: 0.14847090108994326
Validation Accuracy: 56.25%
Test Accuracy: 70.3125%
Epoch 2/20, Loss: 0.08260875935466286
Validation Accuracy: 100.0%
Test Accuracy: 90.46875%
Epoch 3/20, Loss: 0.07599873047756271
Validation Accuracy: 50.0%
Test Accuracy: 64.21875%
Epoch 4/20, Loss: 0.07144786422555136
Validation Accuracy: 81.25%
Test Accuracy: 83.125%
Epoch 5/20, Loss: 0.06761805377072123
Validation Accuracy: 62.5%
Test Accuracy: 74.6875%
Epoch 6/20, Loss: 0.05170202455226263
Validation Accuracy: 75.0%
Test Accuracy: 84.6875%
Epoch 7/20, Loss: 0.07316397230906492
Validation Accuracy: 62.5%
Test Accuracy: 75.3125%
Epoch 8/20, Loss: 0.04355317764548425
Validation Accuracy: 87.5%
Test Accuracy: 77.03125%
Epoch 9/20, Loss: 0.05352595068608622
Validation Accuracy: 81.25%
Test Accuracy: 84.375%
Epoch 10/20, Loss: 0.043679054630091814
Validation Accuracy: 93.75%
Test Accuracy: 84.84375%
Epoch 11/20, Loss: 0.03595333333656426
Validation Accuracy: 93.75%
Test Accuracy: 87.65625%
Epoch 12/20, Loss: 0.045746906891899426
Validation Accuracy: 68.75%
Test Accuracy: 76.25%
Epoch 13/20, Loss: 0.04264523496814186
Validation Accuracy: 68.75%
Test Accuracy: 78.59375%
Epoch 14/20, Loss: 0.03777799939894206
Validation Accuracy: 68.75%
Test Accuracy: 84.375%
Epoch 15/20, Loss: 0.03703763244989288
Validation Accuracy: 100.0%
Test Accuracy: 84.84375%
Epoch 16/20, Loss: 0.044358568155510994
Validation Accuracy: 100.0%
Test Accuracy: 88.4375%
Epoch 17/20, Loss: 0.034426353409107165
Validation Accuracy: 100.0%
Test Accuracy: 84.375%
Epoch 18/20, Loss: 0.03374421215802574
Validation Accuracy: 81.25%
Test Accuracy: 82.34375%
Epoch 19/20, Loss: 0.03210519103930072
Validation Accuracy: 81.25%
Test Accuracy: 83.28125%
Epoch 20/20, Loss: 0.03278942145903572
Validation Accuracy: 68.75%
Test Accuracy: 84.21875%
"""

# Extract the data using regular expressions
epochs = range(1, 21)
training_loss = re.findall(r'Loss: (\d+\.\d+)', text)
validation_accuracy = re.findall(r'Validation Accuracy: (\d+\.\d+)%', text)
test_accuracy = re.findall(r'Test Accuracy: (\d+\.\d+)%', text)

# Convert the extracted strings to floats
training_loss = [float(loss) for loss in training_loss]
validation_accuracy = [float(acc) for acc in validation_accuracy]
test_accuracy = [float(acc) for acc in test_accuracy]

# Display the lists
training_loss, validation_accuracy, test_accuracy
# Out:
# ([0.14847090108994326,
#   0.08260875935466286,
#   0.07599873047756271,
#   0.07144786422555136,
#   0.06761805377072123,
#   0.05170202455226263,
#   0.07316397230906492,
#   0.04355317764548425,
#   0.05352595068608622,
#   0.043679054630091814,
#   0.03595333333656426,
#   0.045746906891899426,
#   0.04264523496814186,
#   0.03777799939894206,
#   0.03703763244989288,
#   0.044358568155510994,
#   0.034426353409107165,
#   0.03374421215802574,
#   0.03210519103930072,
#   0.03278942145903572],
#  [56.25,
#   100.0,
#   50.0,
#   81.25,
#   62.5,
#   75.0,
#   62.5,
#   87.5,
#   81.25,
#   93.75,
#   93.75,
#   68.75,
#   68.75,
#   68.75,
#   100.0,
#   100.0,
#   100.0,
#   81.25,
#   81.25,
#   68.75],
#  [70.3125,
#   90.46875,
#   64.21875,
#   83.125,
#   74.6875,
#   84.6875,
#   75.3125,
#   77.03125,
#   84.375,
#   84.84375,
#   87.65625,
#   76.25,
#   78.59375,
#   84.375,
#   84.84375,
#   88.4375,
#   84.375,
#   82.34375,
#   83.28125,
#   84.21875])

# %%
#DenseNet121
import matplotlib.pyplot as plt

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
#training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
#training_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy, color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for ResNet-18 ')
fig.tight_layout()

plt.savefig("ResNet18_20_p001.pdf")

# Show plot
plt.show()

print("Average Test Accuracy(%):"+str(average(test_accuracy)))
print("Average Highest Test Accuracy(%):"+str(max(test_accuracy)))
# Out:
# Average Test Accuracy(%):81.171875
# Average Highest Test Accuracy(%):90.46875

# %%
text = """Epoch 1/20, Loss: 0.6425753329063486
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 2/20, Loss: 0.575569212436676
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 3/20, Loss: 0.5714464639227814
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 4/20, Loss: 0.5724187848026767
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 5/20, Loss: 0.5731204856027123
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 6/20, Loss: 0.573713638116977
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 7/20, Loss: 0.5711681031010634
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 8/20, Loss: 0.5735202747985629
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 9/20, Loss: 0.5728176980296527
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 10/20, Loss: 0.5720699729363611
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 11/20, Loss: 0.5712563856247744
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 12/20, Loss: 0.5723329702037975
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 13/20, Loss: 0.5719697182895216
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 14/20, Loss: 0.5722438647337487
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 15/20, Loss: 0.5724268423999014
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 16/20, Loss: 0.5728542769979115
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 17/20, Loss: 0.5703884761757646
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 18/20, Loss: 0.5725782970709303
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 19/20, Loss: 0.5714592346750154
Validation Accuracy: 50.0%
Test Accuracy: 62.5%
Epoch 20/20, Loss: 0.5722118707522292
Validation Accuracy: 50.0%
Test Accuracy: 62.5%"""


# Extract the data using regular expressions
epochs = range(1, 21)
training_loss = re.findall(r'Loss: (\d+\.\d+)', text)
validation_accuracy = re.findall(r'Validation Accuracy: (\d+\.\d+)%', text)
test_accuracy = re.findall(r'Test Accuracy: (\d+\.\d+)%', text)

# Convert the extracted strings to floats
training_loss = [float(loss) for loss in training_loss]
validation_accuracy = [float(acc) for acc in validation_accuracy]
test_accuracy = [float(acc) for acc in test_accuracy]

# Display the lists
training_loss, validation_accuracy, test_accuracy
# Out:
# ([0.6425753329063486,
#   0.575569212436676,
#   0.5714464639227814,
#   0.5724187848026767,
#   0.5731204856027123,
#   0.573713638116977,
#   0.5711681031010634,
#   0.5735202747985629,
#   0.5728176980296527,
#   0.5720699729363611,
#   0.5712563856247744,
#   0.5723329702037975,
#   0.5719697182895216,
#   0.5722438647337487,
#   0.5724268423999014,
#   0.5728542769979115,
#   0.5703884761757646,
#   0.5725782970709303,
#   0.5714592346750154,
#   0.5722118707522292],
#  [50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0,
#   50.0],
#  [62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5,
#   62.5])

# %%
#AlexNet
import matplotlib.pyplot as plt

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
#training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
#training_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy, color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for AlexNet ')
fig.tight_layout()  
plt.savefig("AlexNet_20_p001.pdf")

# Show plot
plt.show()
print("Average Test Accuracy(%):"+str(average(test_accuracy)))
print("Average Highest Test Accuracy(%):"+str(max(test_accuracy)))
# Out:
# Average Test Accuracy(%):62.5
# Average Highest Test Accuracy(%):62.5

# %%
#vgg16
text = """Epoch 1/20, Training Loss: 0.4413922432262988
Epoch 1, Validation Accuracy: 93.75%
Epoch 1, Test Accuracy: 88.14%
Epoch 2/20, Training Loss: 0.24962903178983334
Epoch 2, Validation Accuracy: 100.00%
Epoch 2, Test Accuracy: 83.49%
Epoch 3/20, Training Loss: 0.2313819032703795
Epoch 3, Validation Accuracy: 100.00%
Epoch 3, Test Accuracy: 86.86%
Epoch 4/20, Training Loss: 0.15431607505344097
Epoch 4, Validation Accuracy: 100.00%
Epoch 4, Test Accuracy: 81.41%
Epoch 5/20, Training Loss: 0.20874274484088295
Epoch 5, Validation Accuracy: 100.00%
Epoch 5, Test Accuracy: 84.94%
Epoch 6/20, Training Loss: 0.13106373870624602
Epoch 6, Validation Accuracy: 100.00%
Epoch 6, Test Accuracy: 85.58%
Epoch 7/20, Training Loss: 0.13259256605888814
Epoch 7, Validation Accuracy: 87.50%
Epoch 7, Test Accuracy: 82.05%
Epoch 8/20, Training Loss: 0.11334933135644218
Epoch 8, Validation Accuracy: 100.00%
Epoch 8, Test Accuracy: 88.62%
Epoch 9/20, Training Loss: 0.15282195849426983
Epoch 9, Validation Accuracy: 100.00%
Epoch 9, Test Accuracy: 82.69%
Epoch 10/20, Training Loss: 0.157855809473158
Epoch 10, Validation Accuracy: 93.75%
Epoch 10, Test Accuracy: 82.69%
Epoch 11/20, Training Loss: 0.13880186951151433
Epoch 11, Validation Accuracy: 100.00%
Epoch 11, Test Accuracy: 89.10%
Epoch 12/20, Training Loss: 0.1709611113441653
Epoch 12, Validation Accuracy: 93.75%
Epoch 12, Test Accuracy: 88.94%
Epoch 13/20, Training Loss: 0.12395849977166426
Epoch 13, Validation Accuracy: 81.25%
Epoch 13, Test Accuracy: 74.84%
Epoch 14/20, Training Loss: 0.1693770763597471
Epoch 14, Validation Accuracy: 100.00%
Epoch 14, Test Accuracy: 87.66%
Epoch 15/20, Training Loss: 0.11161401189975477
Epoch 15, Validation Accuracy: 100.00%
Epoch 15, Test Accuracy: 84.78%
Epoch 16/20, Training Loss: 0.12695626695490403
Epoch 16, Validation Accuracy: 100.00%
Epoch 16, Test Accuracy: 88.78%
Epoch 17/20, Training Loss: 0.14918819297309693
Epoch 17, Validation Accuracy: 100.00%
Epoch 17, Test Accuracy: 85.10%
Epoch 18/20, Training Loss: 0.08346103787732145
Epoch 18, Validation Accuracy: 100.00%
Epoch 18, Test Accuracy: 86.86%
Epoch 19/20, Training Loss: 0.1104334441963169
Epoch 19, Validation Accuracy: 93.75%
Epoch 19, Test Accuracy: 85.74%
Epoch 20/20, Training Loss: 0.08756081477426095
Epoch 20, Validation Accuracy: 100.00%
Epoch 20, Test Accuracy: 85.90%"""


# Extract the data using regular expressions
epochs = range(1, 21)
training_loss = re.findall(r'Loss: (\d+\.\d+)', text)
validation_accuracy = re.findall(r'Validation Accuracy: (\d+\.\d+)%', text)
test_accuracy = re.findall(r'Test Accuracy: (\d+\.\d+)%', text)

# Convert the extracted strings to floats
training_loss = [float(loss) for loss in training_loss]
validation_accuracy = [float(acc) for acc in validation_accuracy]
test_accuracy_0 = [float(acc) for acc in test_accuracy]

# Display the lists
training_loss, validation_accuracy, test_accuracy
print(training_loss)

c = 0 
for ele in training_loss :
    if c >= 9:
        training_loss[c] = ele * (0.00001)
    c=c+1
#AlexNet
import matplotlib.pyplot as plt

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
#training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
#training_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy_0, color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for VGG16')
fig.tight_layout()  
plt.savefig("vgg16_20_p001.pdf")

# Show plot
plt.show()
print("Average Test Accuracy(%):"+str(average(test_accuracy_0)))
print("Average Highest Test Accuracy(%):"+str(max(test_accuracy_0)))
# Out:
# [0.4413922432262988, 0.24962903178983334, 0.2313819032703795, 0.15431607505344097, 0.20874274484088295, 0.13106373870624602, 0.13259256605888814, 0.11334933135644218, 0.15282195849426983, 0.157855809473158, 0.13880186951151433, 0.1709611113441653, 0.12395849977166426, 0.1693770763597471, 0.11161401189975477, 0.12695626695490403, 0.14918819297309693, 0.08346103787732145, 0.1104334441963169, 0.08756081477426095]
# Average Test Accuracy(%):85.20849999999999
# Average Highest Test Accuracy(%):89.1

# %%
text = """Epoch 1/20, Loss: 0.34061336271647663
Validation Accuracy: 87.5%
Test Accuracy: 74.67948717948718%
Epoch 2/20, Loss: 0.07293965258104212
Validation Accuracy: 100.0%
Test Accuracy: 82.37179487179488%
Epoch 3/20, Loss: 0.03780929441528075
Validation Accuracy: 87.5%
Test Accuracy: 77.08333333333333%
Epoch 4/20, Loss: 0.019738213354121733
Validation Accuracy: 75.0%
Test Accuracy: 70.3525641025641%
Epoch 5/20, Loss: 0.01906484283023979
Validation Accuracy: 87.5%
Test Accuracy: 73.3974358974359%
Epoch 6/20, Loss: 0.0036249541123758323
Validation Accuracy: 81.25%
Test Accuracy: 75.0%
Epoch 7/20, Loss: 0.000788282469153954
Validation Accuracy: 81.25%
Test Accuracy: 75.0%
Epoch 8/20, Loss: 0.00019697701913818117
Validation Accuracy: 81.25%
Test Accuracy: 74.51923076923077%
Epoch 9/20, Loss: 0.00011921529111800263
Validation Accuracy: 81.25%
Test Accuracy: 74.35897435897436%
Epoch 10/20, Loss: 8.58302283887201e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.83974358974359%
Epoch 11/20, Loss: 6.538513674440987e-05
Validation Accuracy: 81.25%
Test Accuracy: 75.16025641025641%
Epoch 12/20, Loss: 5.242542954542116e-05
Validation Accuracy: 81.25%
Test Accuracy: 75.0%
Epoch 13/20, Loss: 4.0818586055425795e-05
Validation Accuracy: 81.25%
Test Accuracy: 72.75641025641026%
Epoch 14/20, Loss: 3.520090472841903e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.67948717948718%
Epoch 15/20, Loss: 2.8407116038790943e-05
Validation Accuracy: 81.25%
Test Accuracy: 75.0%
Epoch 16/20, Loss: 2.3550846681887852e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.67948717948718%
Epoch 17/20, Loss: 1.9662309089624425e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.83974358974359%
Epoch 18/20, Loss: 1.6508088378026043e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.51923076923077%
Epoch 19/20, Loss: 1.3919946443595208e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.35897435897436%
Epoch 20/20, Loss: 1.2344789193361502e-05
Validation Accuracy: 81.25%
Test Accuracy: 74.67948717948718%"""


# Extract the data using regular expressions
epochs = range(1, 21)
training_loss = re.findall(r'Loss: (\d+\.\d+)', text)
validation_accuracy = re.findall(r'Validation Accuracy: (\d+\.\d+)%', text)
test_accuracy = re.findall(r'Test Accuracy: (\d+\.\d+)%', text)

# Convert the extracted strings to floats
training_loss = [float(loss) for loss in training_loss]
validation_accuracy = [float(acc) for acc in validation_accuracy]
test_accuracy_0 = [float(acc) for acc in test_accuracy]

# Display the lists
training_loss, validation_accuracy, test_accuracy
print(training_loss)

c = 0 
for ele in training_loss :
    if c >= 9:
        training_loss[c] = ele * (0.00001)
    c=c+1
#AlexNet
import matplotlib.pyplot as plt

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
#training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
#training_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy_0, color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for Generic CNN')
fig.tight_layout()  
plt.savefig("BasicCNN_20_p001.pdf")

# Show plot
plt.show()

print("Average Test Accuracy(%):"+str(average(test_accuracy_0)))
print("Average Highest Test Accuracy(%):"+str(max(test_accuracy_0)))
# Out:
# [0.34061336271647663, 0.07293965258104212, 0.03780929441528075, 0.019738213354121733, 0.01906484283023979, 0.0036249541123758323, 0.000788282469153954, 0.00019697701913818117, 0.00011921529111800263, 8.58302283887201, 6.538513674440987, 5.242542954542116, 4.081858605542579, 3.520090472841903, 2.8407116038790945, 2.3550846681887854, 1.9662309089624426, 1.6508088378026042, 1.3919946443595208, 1.2344789193361503]
# Average Test Accuracy(%):74.86378205128206
# Average Highest Test Accuracy(%):82.37179487179488

# %%
#basic cnn with data augmentation
text = """Epoch 1/20, Loss: 0.2977103197810017
Validation Accuracy: 75.0%
Test Accuracy: 81.25%
Epoch 2/20, Loss: 0.11053484615989806
Validation Accuracy: 68.75%
Test Accuracy: 76.28205128205128%
Epoch 3/20, Loss: 0.098603746913762
Validation Accuracy: 62.5%
Test Accuracy: 80.60897435897436%
Epoch 4/20, Loss: 0.08681882552708288
Validation Accuracy: 50.0%
Test Accuracy: 78.36538461538461%
Epoch 5/20, Loss: 0.08807716566349374
Validation Accuracy: 56.25%
Test Accuracy: 71.47435897435898%
Epoch 6/20, Loss: 0.07501501939116628
Validation Accuracy: 68.75%
Test Accuracy: 76.12179487179488%
Epoch 7/20, Loss: 0.06873277269937297
Validation Accuracy: 56.25%
Test Accuracy: 68.75%
Epoch 8/20, Loss: 0.0667259337686208
Validation Accuracy: 62.5%
Test Accuracy: 72.59615384615384%
Epoch 9/20, Loss: 0.06381468534001086
Validation Accuracy: 62.5%
Test Accuracy: 77.40384615384616%
Epoch 10/20, Loss: 0.0505740341699705
Validation Accuracy: 68.75%
Test Accuracy: 78.84615384615384%
Epoch 11/20, Loss: 0.0567695811402304
Validation Accuracy: 68.75%
Test Accuracy: 76.6025641025641%
Epoch 12/20, Loss: 0.047802873423603
Validation Accuracy: 75.0%
Test Accuracy: 73.23717948717949%
Epoch 13/20, Loss: 0.044720288723895746
Validation Accuracy: 81.25%
Test Accuracy: 80.60897435897436%
Epoch 14/20, Loss: 0.04871528180447504
Validation Accuracy: 75.0%
Test Accuracy: 79.6474358974359%
Epoch 15/20, Loss: 0.0426431347948479
Validation Accuracy: 68.75%
Test Accuracy: 74.67948717948718%
Epoch 16/20, Loss: 0.03792616338154838
Validation Accuracy: 68.75%
Test Accuracy: 73.87820512820512%
Epoch 17/20, Loss: 0.04037327717981113
Validation Accuracy: 68.75%
Test Accuracy: 76.76282051282051%
Epoch 18/20, Loss: 0.03596452993742173
Validation Accuracy: 68.75%
Test Accuracy: 74.83974358974359%
Epoch 19/20, Loss: 0.02594850248003402
Validation Accuracy: 75.0%
Test Accuracy: 80.76923076923077%
Epoch 20/20, Loss: 0.030690683019090375
Validation Accuracy: 62.5%
Test Accuracy: 74.35897435897436%"""


# Extract the data using regular expressions
epochs = range(1, 21)
training_loss = re.findall(r'Loss: (\d+\.\d+)', text)
validation_accuracy = re.findall(r'Validation Accuracy: (\d+\.\d+)%', text)
test_accuracy = re.findall(r'Test Accuracy: (\d+\.\d+)%', text)

# Convert the extracted strings to floats
training_loss = [float(loss) for loss in training_loss]
validation_accuracy = [float(acc) for acc in validation_accuracy]
test_accuracy_1 = [float(acc) for acc in test_accuracy]

# Display the lists
training_loss, validation_accuracy, test_accuracy
print(training_loss)

# c = 0 
# for ele in training_loss :
#     if c >= 9:
#         training_loss[c] = ele * (0.00001)
#     c=c+1
#AlexNet
import matplotlib.pyplot as plt

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
#training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
#training_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy_1, color='tab:blue', label = '2')
ax2.plot(epochs, test_accuracy_0, color='tab:green', label = '1')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for Generic CNN')
fig.tight_layout()  
plt.savefig("BasicCNN_aug_20_p001.pdf")

# Show plot
plt.show()

print("Average Test Accuracy(%):"+str(average(test_accuracy_1)))
print("Average Highest Test Accuracy(%):"+str(max(test_accuracy_1)))
# Out:
# [0.2977103197810017, 0.11053484615989806, 0.098603746913762, 0.08681882552708288, 0.08807716566349374, 0.07501501939116628, 0.06873277269937297, 0.0667259337686208, 0.06381468534001086, 0.0505740341699705, 0.0567695811402304, 0.047802873423603, 0.044720288723895746, 0.04871528180447504, 0.0426431347948479, 0.03792616338154838, 0.04037327717981113, 0.03596452993742173, 0.02594850248003402, 0.030690683019090375]
# Average Test Accuracy(%):76.35416666666666
# Average Highest Test Accuracy(%):81.25

# %%
training_loss = [0.39856,0.22081,0.176,0.15971,0.14087,0.1432,0.12686,0.12519,0.1023,0.11013,0.10113,0.10898,0.09473,0.09701,0.08456,0.08455,0.09139,0.09111,0.08535,0.08684]
test_accuracy = [0.8734,0.89263,0.91026,0.91506,0.92308,0.91667,0.91346,0.91827,0.90385,0.88622,0.92628,0.90224,0.91506,0.92788,0.91346,0.89904,0.92949,0.91667,0.92308,0.93429]

# Sample data - replace these with your actual data
epochs = list(range(1, 21))  # 20 epochs
#training_loss = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]  # Sample loss values
#training_accuracy = [82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]  # Sample accuracy values

# Creating plot with dual y-axes
fig, ax1 = plt.subplots()

# Plotting the loss
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss', color='tab:red')
ax1.plot(epochs, training_loss, color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Creating a second y-axis for accuracy
ax2 = ax1.twinx()  
ax2.set_ylabel('Test Accuracy (%)', color='tab:blue')  
ax2.plot(epochs, test_accuracy, color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and layout
plt.title('Training Loss and Test Accuracy over Epochs for YOLOv8')
fig.tight_layout()  
plt.savefig("YOLOv8_20_p001.pdf")

# Show plot
plt.show()

print("Average Test Accuracy(%):"+str(average(test_accuracy)*100))
print("Average Highest Test Accuracy(%):"+str(max(test_accuracy)*100))
# Out:
# Average Test Accuracy(%):91.20195000000001
# Average Highest Test Accuracy(%):93.429

# %%
#training_loss_densenet = [0.1366008538,0.08905085922,0.09228986398,0.06954126488,0.07405919526,0.05925533127,0.06224928194,0.0504604843,0.051904475,0.05050051784,0.04165369104,0.0602361112,0.0467073233,0.0423721772,0.0429702253,0.03661346139,0.03603739695,0.04864419788,0.0389103368,0.03490951911]
#[82.05,	64.26,	84.94,	73.72,	89.90,	80.45,	75.64,	91.83,	82.05,	87.02,	83.17,	75.96,	87.34,	85.42,	76.60,	84.94,	83.81,	79.17,	85.74,	83.33]
